# %% [markdown]
# # Preprocesado de datos en series temporales: ejercicio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns

# %% [markdown]
# En este ejercicio se propone analizar la serie temporal de producción de cerveza en Australia (monthly-beer-production-in-austr.csv). Para ello, se deberán seguir los siguientes pasos:
#
# 1. Transforma la variable Month a una de tipo fecha y añádela como índice.
# 2. Analiza si existen NA en la serie. Si es así, rellénalos.
# 3. Visualiza la serie temporal y la distribución de la serie temporal.
# 4. Analiza la estacionariedad de la serie mediante:
#
#     a) Test de hipótesis.
#
#     b) qqplot
#
#     c) Autocorrelación y autocorrelación parcial.
# 5. Analiza el tipo de serie y, en base a eso selecciona el tipo de descomposición adecuada. Descompón la serie temporal en tendencia, estacionalidad y residuos.
#
#     a) ¿Qué tendencia tiene la serie?
#
#     b) ¿Tiene componente estacional?¿Cada cuánto tiempo se repite el período?
#
#     c) Analiza si los residuos corresponden a ruido blanco. Visualiza la distribución de los residuos.

# %%
beer = pd.read_csv("monthly-beer-production-in-austr.csv")
beer.head()

# %% [markdown]
# ###1. Transforma la variable Month a una de tipo fecha y añádela como índice.

# %% [markdown]
# ###2. Analiza si existen NA en la serie. Si es así, rellénalos.

# %% [markdown]
# ###3. Visualiza la serie temporal y la distribución de la serie temporal.

# %% [markdown]
# ###4. Analiza la estacionariedad de la serie mediante:

# %% [markdown]
# 1) Test de hipótesis (Prueba Dickey-Fuller)

# %%
# H0= No estacionaria
# H1= Sí es estacionaria
# Si p-valor es menor de 0.05, se rechaza la H0

# %% [markdown]
# 2) Gráfico Q-Q (cuartil-cuartil)

# %% [markdown]
# 3) Autocorrelación y autocorrelación parcial

# %% [markdown]
# ###5. Analiza el tipo de serie y, en base a eso selecciona el tipo de descomposición adecuada. Descompón la serie temporal en tendencia, estacionalidad y residuos.

# %% [markdown]
# # EOF (End Of File)
